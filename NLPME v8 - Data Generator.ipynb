# %%
#Different Data to fill
'''
dataType=[
          "integer","integers", "int","ints",
          "float", "floats", 
          "number", "numbers", "num","nums",
          "variable", "variables", "var", "vars",
          "double", "doubles",
          
          "character", "characters", "char", "chars", 
          "string", "strings", "str", "strs", 
          "text", "texts", "txt", "txts",
          
          "array", "arrays",
          "list", "lists",
          "vector", "vectors",
          
          "boolean", "booleans", "bool", "bools"
          
          "void", "voids",
          "class", "classes"
         ]
'''
dataType_number = [ 
                    "integer", "integers", "int","ints",
                    "float", "floats", 
                    "number", "numbers", "num","nums",
                    "variable", "variables", "var", "vars",
                    "double", "doubles"
                   ]

dataType_char = [
                  "character", "characters", "char", "chars", 
                  "string", "strings", "str", "strs", 
                  "text", "texts", "txt", "txts"
                ]

dataType_list = ["array", "arrays", "list", "lists", "vector", "vectors"]
dataType_bool = ["boolean", "booleans", "bool", "bools"]
dataType_class = ["class", "classes"]
dataType_void = ["void", "voids"]

dataType = dataType_number + dataType_char + dataType_list + dataType_bool + dataType_class + dataType_void

scope_of_variable = ["global", "local", ""]

operators = [
             "addition","add","+", 
             "subtraction", "sub","-", "minus", 
             "multiply", "mul", "*",
             "divide", "div", "/",
             "modulo", "modulus", "mod", "%"
            ]

command_declare = ["create","creates", "define","defines", "declare", "declares", "set", "sets"]
command_print = ["print", "prints", "display", "displays", "show", "shows"]
command_input = ["get", "input"]

special_class = ["log", "printer"]# ,"database"
special_function = ["save"]

# %%
#function to create variables

def generate_variable(dataFill, append_extra=False):
    return_list = []
    s_included = False
    
    for each_dataFill in dataFill:
        if (s_included==False):
                for i in range(0,3):
                    return_list.append(each_dataFill+str(i))
                    s_included = True
        else:
            s_included = False
            
    if (append_extra==True):        
        return_list.append("i")
        return_list.append("j")
        return_list.append("k")
        return_list.append("a")
        return_list.append("b")
        return_list.append("c")
        
    return (return_list)
            
#print (variables_list)
#print(generate_variable(dataType_number))
#print(generate_variable(dataType_char))
#print(generate_variable(dataType_list, True))
#print(generate_variable(["var"]))

# %%
#Prepare Data

#DTYPE
#DTYPE_NUM
#DTYPE_CHAR
#DTYPE_ARRAY
#DTYPE_BOOL
#DTYPE_CLASS
#DTYPE_VOID

#SCOPE_OFVAR
#OPER
#CMD_DECL
#CMD_PRNT
#CMD_INPUT
#VARI
#RAND_NUM

input_txt=[]

input_txt=["CMD_DECL SCOPE_OFVAR DTYPE",  #define global variable 
           "CMD_DECL DTYPE VARI=RAND_NUM",  #set variable i=10
           "CMD_DECL SCOPE_OFVAR DTYPE VARI",  #create variable i
           "CMD_DECL SCOPE_OFVAR DTYPE equal to RAND_NUM",  #set variable equal to 10
           "CMD_DECL SCOPE_OFVAR DTYPE VARI equal to RAND_NUM",  #set variable i equal to 10
           "CMD_DECL SCOPE_OFVAR DTYPE VARI=RAND_NUM", #define variable i      
           "CMD_DECL SCOPE_OFVAR DTYPE equal VARI to RAND_NUM",  #set variable equal j to 0
          ]

# %%
def generate_partial_data(txt_code, datafill_list, input_list):
        
    returnList = []
    
    for eachLine in input_list:
        if txt_code in eachLine:
            for eachData in datafill_list:
                tmp_txt = eachLine.replace(txt_code, eachData)
                tmp_txt = tmp_txt.replace("  "," ")
                returnList.append(tmp_txt)
                #print("tmp_txt: {}".format(tmp_txt))
        else:
            returnList.append(eachLine)
    return (returnList)

def generate_partial_data_DTYPE(txt_code, datafill_list, input_list):
        
    returnList = []
    
    for eachLine in input_list:
        if txt_code in eachLine:
            for eachData in datafill_list:
                tmp_txt = eachLine.replace(txt_code, eachData)
                tmp_txt = tmp_txt.replace("  "," ")
                returnList.append(tmp_txt)
                if "VARI" in eachLine:
                    
                    tmp_var_list = generate_variable([eachData])
                    tmp_list = generate_partial_data("VARI", tmp_var_list, returnList)
                    #returnList = returnList + tmp_list
                    #print ("EachData : "+eachData)
                    #print ("tmp_var_list: {}".format(tmp_var_list))
                    #print("returnList: {}".format(returnList))
                #print("tmp_txt: {}".format(tmp_txt))
        else:
            returnList.append(eachLine)
    return (returnList)
    '''
    generate_variable()
    for eachLine in input_txt:
        if "SCOPE_OFVAR" in eachLine:
            for each_scope in scope_of_variable:
                tmp_txt = eachLine.replace("SCOPE_OFVAR", each_scope)
                output_list.append( tmp_txt )
        else:
            output_list.append(eachLine)
    '''
#temp_gen_data1=["CMD_DECL SCOPE_OFVAR DTYPE"]
#print(my_func ("DTYPE", dataType, temp_gen_data1))

# %%
#Substitute and create dataset
import random

generated_data = []

for eachLine in input_txt:
    print (eachLine)
    
    temp_gen_data1=[eachLine]
    #temp_gen_data2 = generate_partial_data ("DTYPE", dataType, temp_gen_data1)
    temp_gen_data2 = generate_partial_data_DTYPE ("DTYPE", dataType, temp_gen_data1)
    '''
    temp_gen_data1=[]
    temp_gen_data1= generate_partial_data ("SCOPE_OFVAR", scope_of_variable, temp_gen_data2)
    
    temp_gen_data2=[]
    temp_gen_data2 = generate_partial_data ("OPER", operators, temp_gen_data1)
    
    temp_gen_data1=[]
    temp_gen_data1= generate_partial_data ("CMD_DECL", command_declare, temp_gen_data2)
    
    temp_gen_data2=[]
    temp_gen_data2 = generate_partial_data ("CMD_PRNT", command_print, temp_gen_data1)
    
    temp_gen_data1=[]
    temp_gen_data1= generate_partial_data ("CMD_INPUT", command_input, temp_gen_data2)
    
    temp_gen_data2=[]
    temp_gen_data2 = generate_partial_data ("VARI", variables_list, temp_gen_data1)
'''
temp_gen_data1=[]
for eachLine in temp_gen_data2:
    if "RAND_NUM" in eachLine:
        random_number = random.randint(0,100)
        tmp_txt = eachLine.replace("RAND_NUM", str(random_number))
        temp_gen_data1.append(tmp_txt)
    else:
        temp_gen_data1.append(eachLine)
    

#print (temp_gen_data2)
#print ("Length: " + str( len(temp_gen_data2) ) )

#print (temp_gen_data1)
print ("Length: " + str( len(temp_gen_data1) ) )
# Out:
# CMD_DECL SCOPE_OFVAR DTYPE
# CMD_DECL DTYPE VARI=RAND_NUM
# EachData : integer
# tmp_var_list: ['integer0', 'integer1', 'integer2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM']
# EachData : integers
# tmp_var_list: ['integers0', 'integers1', 'integers2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM']
# EachData : int
# tmp_var_list: ['int0', 'int1', 'int2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM']
# EachData : ints
# tmp_var_list: ['ints0', 'ints1', 'ints2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM']
# EachData : float
# tmp_var_list: ['float0', 'float1', 'float2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM']
# EachData : floats
# tmp_var_list: ['floats0', 'floats1', 'floats2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM']
# EachData : number
# tmp_var_list: ['number0', 'number1', 'number2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM']
# EachData : numbers
# tmp_var_list: ['numbers0', 'numbers1', 'numbers2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM']
# EachData : num
# tmp_var_list: ['num0', 'num1', 'num2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM']
# EachData : nums
# tmp_var_list: ['nums0', 'nums1', 'nums2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM']
# EachData : variable
# tmp_var_list: ['variable0', 'variable1', 'variable2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM']
# EachData : variables
# tmp_var_list: ['variables0', 'variables1', 'variables2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM']
# EachData : var
# tmp_var_list: ['var0', 'var1', 'var2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM']
# EachData : vars
# tmp_var_list: ['vars0', 'vars1', 'vars2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM']
# EachData : double
# tmp_var_list: ['double0', 'double1', 'double2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM']
# EachData : doubles
# tmp_var_list: ['doubles0', 'doubles1', 'doubles2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM']
# EachData : character
# tmp_var_list: ['character0', 'character1', 'character2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM']
# EachData : characters
# tmp_var_list: ['characters0', 'characters1', 'characters2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM']
# EachData : char
# tmp_var_list: ['char0', 'char1', 'char2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM']
# EachData : chars
# tmp_var_list: ['chars0', 'chars1', 'chars2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM']
# EachData : string
# tmp_var_list: ['string0', 'string1', 'string2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM']
# EachData : strings
# tmp_var_list: ['strings0', 'strings1', 'strings2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM']
# EachData : str
# tmp_var_list: ['str0', 'str1', 'str2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM']
# EachData : strs
# tmp_var_list: ['strs0', 'strs1', 'strs2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM']
# EachData : text
# tmp_var_list: ['text0', 'text1', 'text2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM']
# EachData : texts
# tmp_var_list: ['texts0', 'texts1', 'texts2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM', 'CMD_DECL texts VARI=RAND_NUM']
# EachData : txt
# tmp_var_list: ['txt0', 'txt1', 'txt2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM', 'CMD_DECL texts VARI=RAND_NUM', 'CMD_DECL txt VARI=RAND_NUM']
# EachData : txts
# tmp_var_list: ['txts0', 'txts1', 'txts2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM', 'CMD_DECL texts VARI=RAND_NUM', 'CMD_DECL txt VARI=RAND_NUM', 'CMD_DECL txts VARI=RAND_NUM']
# EachData : array
# tmp_var_list: ['array0', 'array1', 'array2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM', 'CMD_DECL texts VARI=RAND_NUM', 'CMD_DECL txt VARI=RAND_NUM', 'CMD_DECL txts VARI=RAND_NUM', 'CMD_DECL array VARI=RAND_NUM']
# EachData : arrays
# tmp_var_list: ['arrays0', 'arrays1', 'arrays2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM', 'CMD_DECL texts VARI=RAND_NUM', 'CMD_DECL txt VARI=RAND_NUM', 'CMD_DECL txts VARI=RAND_NUM', 'CMD_DECL array VARI=RAND_NUM', 'CMD_DECL arrays VARI=RAND_NUM']
# EachData : list
# tmp_var_list: ['list0', 'list1', 'list2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM', 'CMD_DECL texts VARI=RAND_NUM', 'CMD_DECL txt VARI=RAND_NUM', 'CMD_DECL txts VARI=RAND_NUM', 'CMD_DECL array VARI=RAND_NUM', 'CMD_DECL arrays VARI=RAND_NUM', 'CMD_DECL list VARI=RAND_NUM']
# EachData : lists
# tmp_var_list: ['lists0', 'lists1', 'lists2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM', 'CMD_DECL texts VARI=RAND_NUM', 'CMD_DECL txt VARI=RAND_NUM', 'CMD_DECL txts VARI=RAND_NUM', 'CMD_DECL array VARI=RAND_NUM', 'CMD_DECL arrays VARI=RAND_NUM', 'CMD_DECL list VARI=RAND_NUM', 'CMD_DECL lists VARI=RAND_NUM']
# EachData : vector
# tmp_var_list: ['vector0', 'vector1', 'vector2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM', 'CMD_DECL texts VARI=RAND_NUM', 'CMD_DECL txt VARI=RAND_NUM', 'CMD_DECL txts VARI=RAND_NUM', 'CMD_DECL array VARI=RAND_NUM', 'CMD_DECL arrays VARI=RAND_NUM', 'CMD_DECL list VARI=RAND_NUM', 'CMD_DECL lists VARI=RAND_NUM', 'CMD_DECL vector VARI=RAND_NUM']
# EachData : vectors
# tmp_var_list: ['vectors0', 'vectors1', 'vectors2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM', 'CMD_DECL texts VARI=RAND_NUM', 'CMD_DECL txt VARI=RAND_NUM', 'CMD_DECL txts VARI=RAND_NUM', 'CMD_DECL array VARI=RAND_NUM', 'CMD_DECL arrays VARI=RAND_NUM', 'CMD_DECL list VARI=RAND_NUM', 'CMD_DECL lists VARI=RAND_NUM', 'CMD_DECL vector VARI=RAND_NUM', 'CMD_DECL vectors VARI=RAND_NUM']
# EachData : boolean
# tmp_var_list: ['boolean0', 'boolean1', 'boolean2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM', 'CMD_DECL texts VARI=RAND_NUM', 'CMD_DECL txt VARI=RAND_NUM', 'CMD_DECL txts VARI=RAND_NUM', 'CMD_DECL array VARI=RAND_NUM', 'CMD_DECL arrays VARI=RAND_NUM', 'CMD_DECL list VARI=RAND_NUM', 'CMD_DECL lists VARI=RAND_NUM', 'CMD_DECL vector VARI=RAND_NUM', 'CMD_DECL vectors VARI=RAND_NUM', 'CMD_DECL boolean VARI=RAND_NUM']
# EachData : booleans
# tmp_var_list: ['booleans0', 'booleans1', 'booleans2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM', 'CMD_DECL texts VARI=RAND_NUM', 'CMD_DECL txt VARI=RAND_NUM', 'CMD_DECL txts VARI=RAND_NUM', 'CMD_DECL array VARI=RAND_NUM', 'CMD_DECL arrays VARI=RAND_NUM', 'CMD_DECL list VARI=RAND_NUM', 'CMD_DECL lists VARI=RAND_NUM', 'CMD_DECL vector VARI=RAND_NUM', 'CMD_DECL vectors VARI=RAND_NUM', 'CMD_DECL boolean VARI=RAND_NUM', 'CMD_DECL booleans VARI=RAND_NUM']
# EachData : bool
# tmp_var_list: ['bool0', 'bool1', 'bool2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM', 'CMD_DECL texts VARI=RAND_NUM', 'CMD_DECL txt VARI=RAND_NUM', 'CMD_DECL txts VARI=RAND_NUM', 'CMD_DECL array VARI=RAND_NUM', 'CMD_DECL arrays VARI=RAND_NUM', 'CMD_DECL list VARI=RAND_NUM', 'CMD_DECL lists VARI=RAND_NUM', 'CMD_DECL vector VARI=RAND_NUM', 'CMD_DECL vectors VARI=RAND_NUM', 'CMD_DECL boolean VARI=RAND_NUM', 'CMD_DECL booleans VARI=RAND_NUM', 'CMD_DECL bool VARI=RAND_NUM']
# EachData : bools
# tmp_var_list: ['bools0', 'bools1', 'bools2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM', 'CMD_DECL texts VARI=RAND_NUM', 'CMD_DECL txt VARI=RAND_NUM', 'CMD_DECL txts VARI=RAND_NUM', 'CMD_DECL array VARI=RAND_NUM', 'CMD_DECL arrays VARI=RAND_NUM', 'CMD_DECL list VARI=RAND_NUM', 'CMD_DECL lists VARI=RAND_NUM', 'CMD_DECL vector VARI=RAND_NUM', 'CMD_DECL vectors VARI=RAND_NUM', 'CMD_DECL boolean VARI=RAND_NUM', 'CMD_DECL booleans VARI=RAND_NUM', 'CMD_DECL bool VARI=RAND_NUM', 'CMD_DECL bools VARI=RAND_NUM']
# EachData : class
# tmp_var_list: ['class0', 'class1', 'class2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM', 'CMD_DECL texts VARI=RAND_NUM', 'CMD_DECL txt VARI=RAND_NUM', 'CMD_DECL txts VARI=RAND_NUM', 'CMD_DECL array VARI=RAND_NUM', 'CMD_DECL arrays VARI=RAND_NUM', 'CMD_DECL list VARI=RAND_NUM', 'CMD_DECL lists VARI=RAND_NUM', 'CMD_DECL vector VARI=RAND_NUM', 'CMD_DECL vectors VARI=RAND_NUM', 'CMD_DECL boolean VARI=RAND_NUM', 'CMD_DECL booleans VARI=RAND_NUM', 'CMD_DECL bool VARI=RAND_NUM', 'CMD_DECL bools VARI=RAND_NUM', 'CMD_DECL class VARI=RAND_NUM']
# EachData : classes
# tmp_var_list: ['classes0', 'classes1', 'classes2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM', 'CMD_DECL texts VARI=RAND_NUM', 'CMD_DECL txt VARI=RAND_NUM', 'CMD_DECL txts VARI=RAND_NUM', 'CMD_DECL array VARI=RAND_NUM', 'CMD_DECL arrays VARI=RAND_NUM', 'CMD_DECL list VARI=RAND_NUM', 'CMD_DECL lists VARI=RAND_NUM', 'CMD_DECL vector VARI=RAND_NUM', 'CMD_DECL vectors VARI=RAND_NUM', 'CMD_DECL boolean VARI=RAND_NUM', 'CMD_DECL booleans VARI=RAND_NUM', 'CMD_DECL bool VARI=RAND_NUM', 'CMD_DECL bools VARI=RAND_NUM', 'CMD_DECL class VARI=RAND_NUM', 'CMD_DECL classes VARI=RAND_NUM']
# EachData : void
# tmp_var_list: ['void0', 'void1', 'void2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM', 'CMD_DECL texts VARI=RAND_NUM', 'CMD_DECL txt VARI=RAND_NUM', 'CMD_DECL txts VARI=RAND_NUM', 'CMD_DECL array VARI=RAND_NUM', 'CMD_DECL arrays VARI=RAND_NUM', 'CMD_DECL list VARI=RAND_NUM', 'CMD_DECL lists VARI=RAND_NUM', 'CMD_DECL vector VARI=RAND_NUM', 'CMD_DECL vectors VARI=RAND_NUM', 'CMD_DECL boolean VARI=RAND_NUM', 'CMD_DECL booleans VARI=RAND_NUM', 'CMD_DECL bool VARI=RAND_NUM', 'CMD_DECL bools VARI=RAND_NUM', 'CMD_DECL class VARI=RAND_NUM', 'CMD_DECL classes VARI=RAND_NUM', 'CMD_DECL void VARI=RAND_NUM']
# EachData : voids
# tmp_var_list: ['voids0', 'voids1', 'voids2']
# returnList: ['CMD_DECL integer VARI=RAND_NUM', 'CMD_DECL integers VARI=RAND_NUM', 'CMD_DECL int VARI=RAND_NUM', 'CMD_DECL ints VARI=RAND_NUM', 'CMD_DECL float VARI=RAND_NUM', 'CMD_DECL floats VARI=RAND_NUM', 'CMD_DECL number VARI=RAND_NUM', 'CMD_DECL numbers VARI=RAND_NUM', 'CMD_DECL num VARI=RAND_NUM', 'CMD_DECL nums VARI=RAND_NUM', 'CMD_DECL variable VARI=RAND_NUM', 'CMD_DECL variables VARI=RAND_NUM', 'CMD_DECL var VARI=RAND_NUM', 'CMD_DECL vars VARI=RAND_NUM', 'CMD_DECL double VARI=RAND_NUM', 'CMD_DECL doubles VARI=RAND_NUM', 'CMD_DECL character VARI=RAND_NUM', 'CMD_DECL characters VARI=RAND_NUM', 'CMD_DECL char VARI=RAND_NUM', 'CMD_DECL chars VARI=RAND_NUM', 'CMD_DECL string VARI=RAND_NUM', 'CMD_DECL strings VARI=RAND_NUM', 'CMD_DECL str VARI=RAND_NUM', 'CMD_DECL strs VARI=RAND_NUM', 'CMD_DECL text VARI=RAND_NUM', 'CMD_DECL texts VARI=RAND_NUM', 'CMD_DECL txt VARI=RAND_NUM', 'CMD_DECL txts VARI=RAND_NUM', 'CMD_DECL array VARI=RAND_NUM', 'CMD_DECL arrays VARI=RAND_NUM', 'CMD_DECL list VARI=RAND_NUM', 'CMD_DECL lists VARI=RAND_NUM', 'CMD_DECL vector VARI=RAND_NUM', 'CMD_DECL vectors VARI=RAND_NUM', 'CMD_DECL boolean VARI=RAND_NUM', 'CMD_DECL booleans VARI=RAND_NUM', 'CMD_DECL bool VARI=RAND_NUM', 'CMD_DECL bools VARI=RAND_NUM', 'CMD_DECL class VARI=RAND_NUM', 'CMD_DECL classes VARI=RAND_NUM', 'CMD_DECL void VARI=RAND_NUM', 'CMD_DECL voids VARI=RAND_NUM']
# CMD_DECL SCOPE_OFVAR DTYPE VARI
# EachData : integer
# tmp_var_list: ['integer0', 'integer1', 'integer2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI']
# EachData : integers
# tmp_var_list: ['integers0', 'integers1', 'integers2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI']
# EachData : int
# tmp_var_list: ['int0', 'int1', 'int2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI']
# EachData : ints
# tmp_var_list: ['ints0', 'ints1', 'ints2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI']
# EachData : float
# tmp_var_list: ['float0', 'float1', 'float2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI']
# EachData : floats
# tmp_var_list: ['floats0', 'floats1', 'floats2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI']
# EachData : number
# tmp_var_list: ['number0', 'number1', 'number2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI']
# EachData : numbers
# tmp_var_list: ['numbers0', 'numbers1', 'numbers2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI']
# EachData : num
# tmp_var_list: ['num0', 'num1', 'num2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI']
# EachData : nums
# tmp_var_list: ['nums0', 'nums1', 'nums2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI', 'CMD_DECL SCOPE_OFVAR nums VARI']
# EachData : variable
# tmp_var_list: ['variable0', 'variable1', 'variable2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI', 'CMD_DECL SCOPE_OFVAR nums VARI', 'CMD_DECL SCOPE_OFVAR variable VARI']
# EachData : variables
# tmp_var_list: ['variables0', 'variables1', 'variables2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI', 'CMD_DECL SCOPE_OFVAR nums VARI', 'CMD_DECL SCOPE_OFVAR variable VARI', 'CMD_DECL SCOPE_OFVAR variables VARI']
# EachData : var
# tmp_var_list: ['var0', 'var1', 'var2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI', 'CMD_DECL SCOPE_OFVAR nums VARI', 'CMD_DECL SCOPE_OFVAR variable VARI', 'CMD_DECL SCOPE_OFVAR variables VARI', 'CMD_DECL SCOPE_OFVAR var VARI']
# EachData : vars
# tmp_var_list: ['vars0', 'vars1', 'vars2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI', 'CMD_DECL SCOPE_OFVAR nums VARI', 'CMD_DECL SCOPE_OFVAR variable VARI', 'CMD_DECL SCOPE_OFVAR variables VARI', 'CMD_DECL SCOPE_OFVAR var VARI', 'CMD_DECL SCOPE_OFVAR vars VARI']
# EachData : double
# tmp_var_list: ['double0', 'double1', 'double2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI', 'CMD_DECL SCOPE_OFVAR nums VARI', 'CMD_DECL SCOPE_OFVAR variable VARI', 'CMD_DECL SCOPE_OFVAR variables VARI', 'CMD_DECL SCOPE_OFVAR var VARI', 'CMD_DECL SCOPE_OFVAR vars VARI', 'CMD_DECL SCOPE_OFVAR double VARI']
# EachData : doubles
# tmp_var_list: ['doubles0', 'doubles1', 'doubles2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI', 'CMD_DECL SCOPE_OFVAR nums VARI', 'CMD_DECL SCOPE_OFVAR variable VARI', 'CMD_DECL SCOPE_OFVAR variables VARI', 'CMD_DECL SCOPE_OFVAR var VARI', 'CMD_DECL SCOPE_OFVAR vars VARI', 'CMD_DECL SCOPE_OFVAR double VARI', 'CMD_DECL SCOPE_OFVAR doubles VARI']
# EachData : character
# tmp_var_list: ['character0', 'character1', 'character2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI', 'CMD_DECL SCOPE_OFVAR nums VARI', 'CMD_DECL SCOPE_OFVAR variable VARI', 'CMD_DECL SCOPE_OFVAR variables VARI', 'CMD_DECL SCOPE_OFVAR var VARI', 'CMD_DECL SCOPE_OFVAR vars VARI', 'CMD_DECL SCOPE_OFVAR double VARI', 'CMD_DECL SCOPE_OFVAR doubles VARI', 'CMD_DECL SCOPE_OFVAR character VARI']
# EachData : characters
# tmp_var_list: ['characters0', 'characters1', 'characters2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI', 'CMD_DECL SCOPE_OFVAR nums VARI', 'CMD_DECL SCOPE_OFVAR variable VARI', 'CMD_DECL SCOPE_OFVAR variables VARI', 'CMD_DECL SCOPE_OFVAR var VARI', 'CMD_DECL SCOPE_OFVAR vars VARI', 'CMD_DECL SCOPE_OFVAR double VARI', 'CMD_DECL SCOPE_OFVAR doubles VARI', 'CMD_DECL SCOPE_OFVAR character VARI', 'CMD_DECL SCOPE_OFVAR characters VARI']
# EachData : char
# tmp_var_list: ['char0', 'char1', 'char2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI', 'CMD_DECL SCOPE_OFVAR nums VARI', 'CMD_DECL SCOPE_OFVAR variable VARI', 'CMD_DECL SCOPE_OFVAR variables VARI', 'CMD_DECL SCOPE_OFVAR var VARI', 'CMD_DECL SCOPE_OFVAR vars VARI', 'CMD_DECL SCOPE_OFVAR double VARI', 'CMD_DECL SCOPE_OFVAR doubles VARI', 'CMD_DECL SCOPE_OFVAR character VARI', 'CMD_DECL SCOPE_OFVAR characters VARI', 'CMD_DECL SCOPE_OFVAR char VARI']
# EachData : chars
# tmp_var_list: ['chars0', 'chars1', 'chars2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI', 'CMD_DECL SCOPE_OFVAR nums VARI', 'CMD_DECL SCOPE_OFVAR variable VARI', 'CMD_DECL SCOPE_OFVAR variables VARI', 'CMD_DECL SCOPE_OFVAR var VARI', 'CMD_DECL SCOPE_OFVAR vars VARI', 'CMD_DECL SCOPE_OFVAR double VARI', 'CMD_DECL SCOPE_OFVAR doubles VARI', 'CMD_DECL SCOPE_OFVAR character VARI', 'CMD_DECL SCOPE_OFVAR characters VARI', 'CMD_DECL SCOPE_OFVAR char VARI', 'CMD_DECL SCOPE_OFVAR chars VARI']
# EachData : string
# tmp_var_list: ['string0', 'string1', 'string2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI', 'CMD_DECL SCOPE_OFVAR nums VARI', 'CMD_DECL SCOPE_OFVAR variable VARI', 'CMD_DECL SCOPE_OFVAR variables VARI', 'CMD_DECL SCOPE_OFVAR var VARI', 'CMD_DECL SCOPE_OFVAR vars VARI', 'CMD_DECL SCOPE_OFVAR double VARI', 'CMD_DECL SCOPE_OFVAR doubles VARI', 'CMD_DECL SCOPE_OFVAR character VARI', 'CMD_DECL SCOPE_OFVAR characters VARI', 'CMD_DECL SCOPE_OFVAR char VARI', 'CMD_DECL SCOPE_OFVAR chars VARI', 'CMD_DECL SCOPE_OFVAR string VARI']
# EachData : strings
# tmp_var_list: ['strings0', 'strings1', 'strings2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI', 'CMD_DECL SCOPE_OFVAR nums VARI', 'CMD_DECL SCOPE_OFVAR variable VARI', 'CMD_DECL SCOPE_OFVAR variables VARI', 'CMD_DECL SCOPE_OFVAR var VARI', 'CMD_DECL SCOPE_OFVAR vars VARI', 'CMD_DECL SCOPE_OFVAR double VARI', 'CMD_DECL SCOPE_OFVAR doubles VARI', 'CMD_DECL SCOPE_OFVAR character VARI', 'CMD_DECL SCOPE_OFVAR characters VARI', 'CMD_DECL SCOPE_OFVAR char VARI', 'CMD_DECL SCOPE_OFVAR chars VARI', 'CMD_DECL SCOPE_OFVAR string VARI', 'CMD_DECL SCOPE_OFVAR strings VARI']
# EachData : str
# tmp_var_list: ['str0', 'str1', 'str2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI', 'CMD_DECL SCOPE_OFVAR nums VARI', 'CMD_DECL SCOPE_OFVAR variable VARI', 'CMD_DECL SCOPE_OFVAR variables VARI', 'CMD_DECL SCOPE_OFVAR var VARI', 'CMD_DECL SCOPE_OFVAR vars VARI', 'CMD_DECL SCOPE_OFVAR double VARI', 'CMD_DECL SCOPE_OFVAR doubles VARI', 'CMD_DECL SCOPE_OFVAR character VARI', 'CMD_DECL SCOPE_OFVAR characters VARI', 'CMD_DECL SCOPE_OFVAR char VARI', 'CMD_DECL SCOPE_OFVAR chars VARI', 'CMD_DECL SCOPE_OFVAR string VARI', 'CMD_DECL SCOPE_OFVAR strings VARI', 'CMD_DECL SCOPE_OFVAR str VARI']
# EachData : strs
# tmp_var_list: ['strs0', 'strs1', 'strs2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI', 'CMD_DECL SCOPE_OFVAR nums VARI', 'CMD_DECL SCOPE_OFVAR variable VARI', 'CMD_DECL SCOPE_OFVAR variables VARI', 'CMD_DECL SCOPE_OFVAR var VARI', 'CMD_DECL SCOPE_OFVAR vars VARI', 'CMD_DECL SCOPE_OFVAR double VARI', 'CMD_DECL SCOPE_OFVAR doubles VARI', 'CMD_DECL SCOPE_OFVAR character VARI', 'CMD_DECL SCOPE_OFVAR characters VARI', 'CMD_DECL SCOPE_OFVAR char VARI', 'CMD_DECL SCOPE_OFVAR chars VARI', 'CMD_DECL SCOPE_OFVAR string VARI', 'CMD_DECL SCOPE_OFVAR strings VARI', 'CMD_DECL SCOPE_OFVAR str VARI', 'CMD_DECL SCOPE_OFVAR strs VARI']
# EachData : text
# tmp_var_list: ['text0', 'text1', 'text2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI', 'CMD_DECL SCOPE_OFVAR nums VARI', 'CMD_DECL SCOPE_OFVAR variable VARI', 'CMD_DECL SCOPE_OFVAR variables VARI', 'CMD_DECL SCOPE_OFVAR var VARI', 'CMD_DECL SCOPE_OFVAR vars VARI', 'CMD_DECL SCOPE_OFVAR double VARI', 'CMD_DECL SCOPE_OFVAR doubles VARI', 'CMD_DECL SCOPE_OFVAR character VARI', 'CMD_DECL SCOPE_OFVAR characters VARI', 'CMD_DECL SCOPE_OFVAR char VARI', 'CMD_DECL SCOPE_OFVAR chars VARI', 'CMD_DECL SCOPE_OFVAR string VARI', 'CMD_DECL SCOPE_OFVAR strings VARI', 'CMD_DECL SCOPE_OFVAR str VARI', 'CMD_DECL SCOPE_OFVAR strs VARI', 'CMD_DECL SCOPE_OFVAR text VARI']
# EachData : texts
# tmp_var_list: ['texts0', 'texts1', 'texts2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer VARI', 'CMD_DECL SCOPE_OFVAR integers VARI', 'CMD_DECL SCOPE_OFVAR int VARI', 'CMD_DECL SCOPE_OFVAR ints VARI', 'CMD_DECL SCOPE_OFVAR float VARI', 'CMD_DECL SCOPE_OFVAR floats VARI', 'CMD_DECL SCOPE_OFVAR number VARI', 'CMD_DECL SCOPE_OFVAR numbers VARI', 'CMD_DECL SCOPE_OFVAR num VARI', 'CMD_DECL SCOPE_OFVAR nums VARI', 'CMD_DECL SCOPE_OFVAR variable VARI', 'CMD_DECL SCOPE_OFVAR variables VARI', 'CMD_DECL SCOPE_OFVAR var VARI', 'CMD_DECL SCOPE_OFVAR vars VARI', 'CMD_DECL SCOPE_OFVAR double VARI', 'CMD_DECL SCOPE_OFVAR doubles VARI', 'CMD_DECL SCOPE_OFVAR character VARI', 'CMD_DECL SCOPE_OFVAR characters VARI', 'CMD_DECL SCOPE_OFVAR char VARI', 'CMD_DECL SCOPE_OFVAR chars VARI', 'CMD_DECL SCOPE_OFVAR string VARI', 'CMD_DECL SCOPE_OFVAR strings VARI', 'CMD_DECL SCOPE_OFVAR str VARI', 'CMD_DECL SCOPE_OFVAR strs VARI', 'CMD_DECL SCOPE_OFVAR text VARI', 'CMD_DECL SCOPE_OFVAR texts VARI']
# EachData : txt
# tmp_var_list: ['txt0', 'txt1', 'txt2']
# ...
# EachData : booleans
# tmp_var_list: ['booleans0', 'booleans1', 'booleans2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR integers equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR int equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR ints equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR float equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR floats equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR number equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR numbers equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR num equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR nums equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR variable equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR variables equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR var equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vars equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR double equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR doubles equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR character equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR characters equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR char equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR chars equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR string equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR strings equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR str equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR strs equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR text equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR texts equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR txt equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR txts equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR array equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR arrays equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR list equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR lists equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vector equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vectors equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR boolean equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR booleans equal VARI to RAND_NUM']
# EachData : bool
# tmp_var_list: ['bool0', 'bool1', 'bool2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR integers equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR int equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR ints equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR float equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR floats equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR number equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR numbers equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR num equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR nums equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR variable equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR variables equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR var equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vars equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR double equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR doubles equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR character equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR characters equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR char equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR chars equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR string equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR strings equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR str equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR strs equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR text equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR texts equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR txt equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR txts equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR array equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR arrays equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR list equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR lists equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vector equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vectors equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR boolean equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR booleans equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR bool equal VARI to RAND_NUM']
# EachData : bools
# tmp_var_list: ['bools0', 'bools1', 'bools2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR integers equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR int equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR ints equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR float equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR floats equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR number equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR numbers equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR num equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR nums equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR variable equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR variables equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR var equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vars equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR double equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR doubles equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR character equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR characters equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR char equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR chars equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR string equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR strings equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR str equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR strs equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR text equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR texts equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR txt equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR txts equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR array equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR arrays equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR list equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR lists equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vector equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vectors equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR boolean equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR booleans equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR bool equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR bools equal VARI to RAND_NUM']
# EachData : class
# tmp_var_list: ['class0', 'class1', 'class2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR integers equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR int equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR ints equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR float equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR floats equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR number equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR numbers equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR num equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR nums equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR variable equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR variables equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR var equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vars equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR double equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR doubles equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR character equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR characters equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR char equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR chars equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR string equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR strings equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR str equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR strs equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR text equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR texts equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR txt equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR txts equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR array equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR arrays equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR list equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR lists equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vector equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vectors equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR boolean equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR booleans equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR bool equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR bools equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR class equal VARI to RAND_NUM']
# EachData : classes
# tmp_var_list: ['classes0', 'classes1', 'classes2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR integers equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR int equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR ints equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR float equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR floats equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR number equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR numbers equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR num equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR nums equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR variable equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR variables equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR var equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vars equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR double equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR doubles equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR character equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR characters equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR char equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR chars equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR string equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR strings equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR str equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR strs equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR text equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR texts equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR txt equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR txts equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR array equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR arrays equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR list equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR lists equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vector equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vectors equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR boolean equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR booleans equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR bool equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR bools equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR class equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR classes equal VARI to RAND_NUM']
# EachData : void
# tmp_var_list: ['void0', 'void1', 'void2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR integers equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR int equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR ints equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR float equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR floats equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR number equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR numbers equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR num equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR nums equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR variable equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR variables equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR var equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vars equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR double equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR doubles equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR character equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR characters equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR char equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR chars equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR string equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR strings equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR str equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR strs equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR text equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR texts equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR txt equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR txts equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR array equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR arrays equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR list equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR lists equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vector equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vectors equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR boolean equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR booleans equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR bool equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR bools equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR class equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR classes equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR void equal VARI to RAND_NUM']
# EachData : voids
# tmp_var_list: ['voids0', 'voids1', 'voids2']
# returnList: ['CMD_DECL SCOPE_OFVAR integer equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR integers equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR int equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR ints equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR float equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR floats equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR number equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR numbers equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR num equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR nums equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR variable equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR variables equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR var equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vars equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR double equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR doubles equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR character equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR characters equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR char equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR chars equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR string equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR strings equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR str equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR strs equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR text equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR texts equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR txt equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR txts equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR array equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR arrays equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR list equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR lists equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vector equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR vectors equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR boolean equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR booleans equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR bool equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR bools equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR class equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR classes equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR void equal VARI to RAND_NUM', 'CMD_DECL SCOPE_OFVAR voids equal VARI to RAND_NUM']
# Length: 42

# %%
#Write data to file

with open ("Output.txt","w") as output_file:
    for data in temp_gen_data1:
        output_file.write("{}\n".format(data))

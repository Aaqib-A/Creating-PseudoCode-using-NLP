# %%
#Different Data to fill

dataType_number = [ 
                    "integer", "integers", "int","ints",
                    "float", "floats", 
                    "number", "numbers", "num","nums",
                    "variable", "variables", "var", "vars",
                    "double", "doubles"
                   ]

dataType_char = [
                  "character", "characters", "char", "chars", 
                  "string", "strings", "str", "strs", 
                  "text", "texts", "txt", "txts"
                ]

dataType_list = ["array", "arrays", "list", "lists", "vector", "vectors"]
dataType_bool = ["boolean", "booleans", "bool", "bools"]
dataType_class = ["class", "classes"]
dataType_void = ["void", "voids"]

dataType = dataType_number + dataType_char + dataType_list + dataType_bool + dataType_class + dataType_void

scope_of_variable = ["global", "local", ""]

operators = [
             "addition","add","+", 
             "subtraction", "sub","-", "minus", 
             "multiply", "mul", "*",
             "divide", "div", "/",
             "modulo", "modulus", "mod", "%"
            ]

command_declare = ["create","creates", "define","defines", "declare", "declares", 
                   "set", "sets", "write", "writes"]
command_print = ["print", "prints", "display", "displays", "show", "shows"]
command_input = ["get", "gets", "input", "inputs"]

func_prog = ["function", "func", "program", "programme", "prog", "prg"]

func_prog_start2 = [
                 "Write a FUNC_PROG to", "Create a FUNC_PROG to", "Write a FUNC_PROG for", "Create a FUNC_PROG for",
                 "Write FUNC_PROG to", "Create FUNC_PROG to","Write FUNC_PROG for", "Create FUNC_PROG for",
                 ""
                ]

func_prog_start = [
                 "Write a program to", "Create a program to", "Write a program for", "Create a program for",
                 "Write a function to", "Create a function to","Write a function for", "Create a function for",
    
                 "Write program to",  "Create program for",
                 "Write function to", "Create function for",
                 ""
                ]

special_class = ["log", "printer", "file","database", "screen"]# ,"database"
special_function = ["save"]

other_tags = ["a", 'to', 'for']
seperators = ["and", ","]
equal_symbol = ["=","equal", "equals", "equal to", "equals to"]

# %%
#function to create variables

def generate_variable(dataFill, append_extra=False):
    return_list = []
    
    for each_dataFill in dataFill:
        
        for i in range(0,3):
            return_list.append(each_dataFill+str(i))
            return_list.append(each_dataFill+"_"+str(i))
            #s_included = True
        '''
        for i in range(10,13):
            return_list.append(each_dataFill+str(i))
            return_list.append(each_dataFill+"_"+str(i))
            s_included = True
        '''
            
            
    if (append_extra==True):        
        return_list.append("i")
        return_list.append("j")
        return_list.append("k")
        #return_list.append("a")
        return_list.append("b")
        return_list.append("c")
        #return_list.append("name")
        return_list.append("address")
        
    return (return_list)
            
#print (variables_list)
#print(generate_variable(dataType))
#print(generate_variable(dataType_char))
#print(generate_variable(dataType_list, True))
#print(generate_variable(["var"]))

variables_list = generate_variable(dataType, True)
print (variables_list)
# Out:
# ['integer0', 'integer_0', 'integer1', 'integer_1', 'integer2', 'integer_2', 'integers0', 'integers_0', 'integers1', 'integers_1', 'integers2', 'integers_2', 'int0', 'int_0', 'int1', 'int_1', 'int2', 'int_2', 'ints0', 'ints_0', 'ints1', 'ints_1', 'ints2', 'ints_2', 'float0', 'float_0', 'float1', 'float_1', 'float2', 'float_2', 'floats0', 'floats_0', 'floats1', 'floats_1', 'floats2', 'floats_2', 'number0', 'number_0', 'number1', 'number_1', 'number2', 'number_2', 'numbers0', 'numbers_0', 'numbers1', 'numbers_1', 'numbers2', 'numbers_2', 'num0', 'num_0', 'num1', 'num_1', 'num2', 'num_2', 'nums0', 'nums_0', 'nums1', 'nums_1', 'nums2', 'nums_2', 'variable0', 'variable_0', 'variable1', 'variable_1', 'variable2', 'variable_2', 'variables0', 'variables_0', 'variables1', 'variables_1', 'variables2', 'variables_2', 'var0', 'var_0', 'var1', 'var_1', 'var2', 'var_2', 'vars0', 'vars_0', 'vars1', 'vars_1', 'vars2', 'vars_2', 'double0', 'double_0', 'double1', 'double_1', 'double2', 'double_2', 'doubles0', 'doubles_0', 'doubles1', 'doubles_1', 'doubles2', 'doubles_2', 'character0', 'character_0', 'character1', 'character_1', 'character2', 'character_2', 'characters0', 'characters_0', 'characters1', 'characters_1', 'characters2', 'characters_2', 'char0', 'char_0', 'char1', 'char_1', 'char2', 'char_2', 'chars0', 'chars_0', 'chars1', 'chars_1', 'chars2', 'chars_2', 'string0', 'string_0', 'string1', 'string_1', 'string2', 'string_2', 'strings0', 'strings_0', 'strings1', 'strings_1', 'strings2', 'strings_2', 'str0', 'str_0', 'str1', 'str_1', 'str2', 'str_2', 'strs0', 'strs_0', 'strs1', 'strs_1', 'strs2', 'strs_2', 'text0', 'text_0', 'text1', 'text_1', 'text2', 'text_2', 'texts0', 'texts_0', 'texts1', 'texts_1', 'texts2', 'texts_2', 'txt0', 'txt_0', 'txt1', 'txt_1', 'txt2', 'txt_2', 'txts0', 'txts_0', 'txts1', 'txts_1', 'txts2', 'txts_2', 'array0', 'array_0', 'array1', 'array_1', 'array2', 'array_2', 'arrays0', 'arrays_0', 'arrays1', 'arrays_1', 'arrays2', 'arrays_2', 'list0', 'list_0', 'list1', 'list_1', 'list2', 'list_2', 'lists0', 'lists_0', 'lists1', 'lists_1', 'lists2', 'lists_2', 'vector0', 'vector_0', 'vector1', 'vector_1', 'vector2', 'vector_2', 'vectors0', 'vectors_0', 'vectors1', 'vectors_1', 'vectors2', 'vectors_2', 'boolean0', 'boolean_0', 'boolean1', 'boolean_1', 'boolean2', 'boolean_2', 'booleans0', 'booleans_0', 'booleans1', 'booleans_1', 'booleans2', 'booleans_2', 'bool0', 'bool_0', 'bool1', 'bool_1', 'bool2', 'bool_2', 'bools0', 'bools_0', 'bools1', 'bools_1', 'bools2', 'bools_2', 'class0', 'class_0', 'class1', 'class_1', 'class2', 'class_2', 'classes0', 'classes_0', 'classes1', 'classes_1', 'classes2', 'classes_2', 'void0', 'void_0', 'void1', 'void_1', 'void2', 'void_2', 'voids0', 'voids_0', 'voids1', 'voids_1', 'voids2', 'voids_2', 'i', 'j', 'k', 'b', 'c', 'address']

# %%
#function to generate function names

def generate_func_names(func_prog_list, operators_list):
    func_name_list = []
    for each_func in func_prog_list:
        for each_oper in operators_list:
            
            if each_oper == "+":
                each_oper = "add"
            elif each_oper == "-":
                each_oper = "minus"
            elif each_oper == "*":
                each_oper = "mul"
            elif each_oper == "/":
                each_oper = "div"
            elif each_oper == "%":
                each_oper = "mod"
            
            func_name = each_func +"_"+ each_oper
            func_name_list.append(func_name)
            
            func_name =  each_oper +"_"+ each_func
            func_name_list.append(func_name)
            
    func_name_list = list( dict.fromkeys(func_name_list) )   #Remove duplicates     
    return func_name_list

func_name = generate_func_names(func_prog, operators)

#print (variables_list)
#len(func_name)

# %%
#Save the data in Shelf
import shelve
import os

dest_file="NLP_Shelfv11//" + "Dict_Lists" + ".shlf"

if not os.path.exists('NLP_Shelfv11'):
    os.makedirs('NLP_Shelfv11')

shelf = shelve.open(dest_file)
shelf["dataType_number"] = dataType_number
shelf["dataType_char"] = dataType_char
shelf["dataType_list"] = dataType_list
shelf["dataType_bool"] = dataType_bool
shelf["dataType_class"] = dataType_class
shelf["dataType_void"] = dataType_void
shelf["dataType"] = dataType

shelf["variables_list"] = variables_list
shelf["func_name"] = func_name

shelf["scope_of_variable"] = scope_of_variable

shelf["operators"] = operators

shelf["command_declare"] = command_declare
shelf["command_print"] = command_print
shelf["command_input"] = command_input

shelf["func_prog"] = func_prog

shelf["special_class"] = special_class
shelf["special_function"] = special_function

shelf["other_tags"] = other_tags
shelf["seperators"] = seperators
shelf["equal_symbol"] = equal_symbol

shelf.close()

# %%
def generate_partial_data(txt_code, datafill_list, input_list):
        
    returnList = []
    
    for eachLine in input_list:
        if txt_code in eachLine:
            for eachData in datafill_list:
                tmp_txt = eachLine.replace(txt_code, eachData)
                tmp_txt = tmp_txt.replace("  "," ")
                tmp_txt = tmp_txt.lstrip()
                returnList.append(tmp_txt)
                #print("tmp_txt: {}".format(tmp_txt))
        else:
            returnList.append(eachLine)
    return (returnList)
    '''
    generate_variable()
    for eachLine in input_txt:
        if "SCOPE_OFVAR" in eachLine:
            for each_scope in scope_of_variable:
                tmp_txt = eachLine.replace("SCOPE_OFVAR", each_scope)
                output_list.append( tmp_txt )
        else:
            output_list.append(eachLine)
    '''

def generate_partial_data_DTYPE(txt_code, datafill_list_param, input_list):
        
    returnList = []
    
    datafill_list = []
    datafill_list += datafill_list_param
    datafill_list.append(" ")
    
    for eachLine in input_list:
        
        if txt_code in eachLine:
            for eachData in datafill_list:
                temp_returnList = []
                tmp_txt = eachLine.replace(txt_code, eachData)
                tmp_txt = tmp_txt.replace("  "," ")
                tmp_txt = tmp_txt.lstrip()
                temp_returnList.append(tmp_txt)
                if "VARI" in eachLine and eachData !=" ":
                    
                    tmp_var_list = generate_variable([eachData],True)
                    tmp_list = generate_partial_data_VARI("VARI", tmp_var_list, temp_returnList)
                    returnList = returnList + tmp_list
                    
                    #print ("EachData : "+eachData)
                    #print ("tmp_var_list: {}".format(tmp_var_list))
                    #print("returnList: {}".format(returnList))
                #print("tmp_txt: {}".format(tmp_txt))
                else:
                    returnList = returnList + temp_returnList          
        else:
            returnList.append(eachLine)
    #print (returnList)
    return (returnList)

def generate_partial_data_VARI(txt_code, datafill_list, input_list):      
    returnList = []
    for eachLine in input_list:
        if txt_code in eachLine:
            count=0
            for eachData in datafill_list: 
                tmp_txt = eachLine
                while (txt_code in tmp_txt):
                    if count >= len(datafill_list):
                        count=0
                        #print("Length :",len(datafill_list))
                    tmp_txt = tmp_txt.replace(txt_code, datafill_list[count],1)
                    count+=1
                #next(datafill_list,"var1") 
                #print("tmp_txt: {}".format(tmp_txt))
                tmp_txt = tmp_txt.replace("  "," ")
                tmp_txt = tmp_txt.lstrip()
                returnList.append(tmp_txt)
        else:
            returnList.append(eachLine)
    return (returnList)

#temp_gen_data1=["CMD_DECL SCOPE_OFVAR DTYPE"]
#print(my_func ("DTYPE", dataType, temp_gen_data1))

# %%
#Substitute and create dataset
import random
def generate_training_data(input_txt):
    generated_data = []
    
    for eachLine in input_txt:
        print ("eachLine: " + eachLine)
        
        temp_gen_data1=[eachLine]
        temp_gen_data2= generate_partial_data_DTYPE ("DTYPE_NUM", dataType_number, temp_gen_data1)
        
        temp_gen_data1=[]
        temp_gen_data1= generate_partial_data_DTYPE ("DTYPE_CHAR", dataType_char, temp_gen_data2)
        
        temp_gen_data2=[]
        temp_gen_data2 = generate_partial_data_DTYPE ("DTYPE_ARRAY", dataType_list, temp_gen_data1)
        
        temp_gen_data1=[]
        temp_gen_data1= generate_partial_data ("DTYPE_BOOL", dataType_bool, temp_gen_data2)
        
        temp_gen_data2=[]
        temp_gen_data2 = generate_partial_data ("DTYPE_CLASS", dataType_class, temp_gen_data1)
        
        temp_gen_data1=[]
        temp_gen_data1= generate_partial_data_DTYPE ("DTYPE_VOID", dataType_void, temp_gen_data2)
        
        temp_gen_data2=[]
        #temp_gen_data2 = generate_partial_data ("DTYPE", dataType, temp_gen_data1)
        temp_gen_data2 = generate_partial_data_DTYPE ("DTYPE", dataType, temp_gen_data1)
        
        
        temp_gen_data1=[]
        temp_gen_data1= generate_partial_data ("SCOPE_OFVAR", scope_of_variable, temp_gen_data2)
        
        temp_gen_data2=[]
        temp_gen_data2 = generate_partial_data ("OPER", operators, temp_gen_data1)
        
        temp_gen_data1=[]
        temp_gen_data1= generate_partial_data ("CMD_DECL", command_declare, temp_gen_data2)
        
        temp_gen_data2=[]
        temp_gen_data2 = generate_partial_data ("CMD_PRNT", command_print, temp_gen_data1)
        
        temp_gen_data1=[]
        temp_gen_data1= generate_partial_data ("CMD_INPUT", command_input, temp_gen_data2)
        
        temp_gen_data2=[]
        temp_gen_data2 = generate_partial_data ("SPL_CLASS", special_class, temp_gen_data1)
        
        temp_gen_data1=[]
        temp_gen_data1= generate_partial_data ("SPL_FUNC", special_function, temp_gen_data2)
        
        temp_gen_data2=[]
        temp_gen_data2 = generate_partial_data ("FUNC_PROG_START", func_prog_start, temp_gen_data1)
        
        temp_gen_data1=[]
        temp_gen_data1= generate_partial_data ("FUNC_PROG", func_prog, temp_gen_data2)
        
        temp_gen_data2=[]
        temp_gen_data2 = generate_partial_data ("OTHER", other_tags, temp_gen_data1)
        #temp_gen_data2=[]
        #temp_gen_data2 = temp_gen_data1
        
        temp_gen_data1=[]
        temp_gen_data1= generate_partial_data ("SEPERATOR", seperators, temp_gen_data2)
        
        temp_gen_data2=[]
        temp_gen_data2 = generate_partial_data ("EQUAL", equal_symbol, temp_gen_data1)
        
        #Buffer - START
        temp_gen_data1=[]
        temp_gen_data1 = temp_gen_data2
        #Buffer - END
        
        temp_gen_data2=[]
        variables_list = generate_variable(dataType, True)
        temp_gen_data2 = generate_partial_data_VARI("VARI", variables_list, temp_gen_data1)
        
        temp_gen_data1=[]
        func_name = generate_func_names(func_prog, operators)
        temp_gen_data1 = generate_partial_data_VARI("FUNC_NAME", func_name, temp_gen_data2)

        generated_data = generated_data + temp_gen_data1
    
    temp_gen_data2=[]
    for eachLine in generated_data:
        if "RAND_NUM" in eachLine:
            random_number = random.randint(0,100)
            tmp_txt = eachLine.replace("RAND_NUM", str(random_number))
            temp_gen_data2.append(tmp_txt)
        else:
            temp_gen_data2.append(eachLine)
    return (temp_gen_data2)
   
    
#training_data = generate_training_data()

#print ("Length: " + str( len(training_data) ) )

# %%
#Prepare Data

#DTYPE_NUM    : dataType_number
#DTYPE_CHAR   : dataType_char
#DTYPE_ARRAY  :dataType_list
#DTYPE_BOOL   :dataType_bool
#DTYPE_CLASS  :dataType_class
#DTYPE_VOID   :dataType_void
#DTYPE : dataType

#SCOPE_OFVAR : scope_of_variable

#OPER : operators
#
#CMD_DECL  : command_declare
#CMD_PRNT  : command_print
#CMD_INPUT : command_input

#SPL_CLASS: special_class   : ["log", "printer"]
#SPL_FUNC: special_function : ["save"]

#FUNC_PROG : func_prog
#FUNC_PROG_START : func_prog_start

#VARI : <Variables>
#FUNC_NAME : <function names>
#RAND_NUM : <Random Number>

input_txt=[]


input_txt=[
        "FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE",  #define global variable  
        "FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE_NUM equal to RAND_NUM",  #set variable equal to 10
        "FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE_NUM VARI=RAND_NUM", #define variable i=10
        "FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE VARI", #define variable i
        "FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE_NUM to RAND_NUM", #set variable equal I to 0
        "FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE equal VARI to RAND_NUM", #define variable equal i to 10 
        "FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE_CHAR = 'hi'", #set text = "hi"
        "FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE_CHAR to 'hi'", #set text to "hi"
        "FUNC_PROG_START CMD_DECL SCOPE_OFVAR VARI = 'hi'", #set txt1 = "hi"
        "FUNC_PROG_START CMD_DECL SCOPE_OFVAR VARI to 'hi'", #set txt1 to "hi"
        "FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE_CHAR VARI = 'please enter value'", #define variable text1="please enter value"
        "FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE_CHAR VARI to 'please enter value'", #define variable text1 to "please enter value"
        "FUNC_PROG_START CMD_PRNT VARI", #print text1
        "FUNC_PROG_START CMD_PRNT 'please select value' ", #print "please select value"
        "FUNC_PROG_START CMD_PRNT 'please select value' + VARI", #print "please select value" + i
        "FUNC_PROG_START CMD_PRNT VARI + i", #print text1 + i
        "FUNC_PROG_START CMD_PRNT 'please select value' + i", #print text1 + i
        "FUNC_PROG_START CMD_INPUT VARI",#input text1
        "FUNC_PROG_START CMD_INPUT 'please enter name'",#input "please enter name"
    
        #--- Was detecting 'qwe' as value. Cannot add to COUNT because of ner training
        #"FUNC_PROG_START OPER two DTYPE_NUM", #Write a program to add two ints
        #"FUNC_PROG_START OPER 3 DTYPE_NUM", #Write a program to add 3 ints
        #"FUNC_PROG_START OPER two DTYPE_NUM", #Write a program to add two ints
        #---
    
        "FUNC_PROG_START add VARI + VARI", #Write a program to add a + b
        "FUNC_PROG_START VARI - VARI", #Write a program to add a + b
        "FUNC_PROG_START divide VARI / VARI", #Write a program to divide a / b
        "FUNC_PROG_START OPER SCOPE_OFVAR DTYPE_NUM VARI and VARI", #Add variables a and b
    
        "FUNC_PROG_START OPER SCOPE_OFVAR DTYPE_NUM VARI = RAND_NUM and SCOPE_OFVAR VARI = RAND_NUM and DTYPE_NUM VARI = RAND_NUM", #create a function to add local number a =10 and num2 = 15 and  global variable b=15
        "FUNC_PROG_START OPER SCOPE_OFVAR DTYPE_NUM VARI, SCOPE_OFVAR VARI = RAND_NUM and SCOPE_OFVAR DTYPE_NUM VARI", #create a function to add local number a, local num2 = 15 and  global variable b
        "FUNC_PROG_START CMD_PRNT DTYPE_CHAR VARI equals to 'some thing something hello there. General Kenobi' on SPL_CLASS"#"display variable text1 equals to 'some thing something hello there. General Kenobi' on screen"
          ]

input_txt2=[
        "CMD_PRNT VARI on screen", # print a on screen
        "CMD_PRNT VARI to SPL_CLASS", # print a to log 
        "SPL_FUNC VARI", #save name
        "SPL_FUNC VARI and VARI", #save name and address
        "SPL_FUNC VARI to SPL_CLASS", #save name to database
        "SPL_FUNC VARI and VARI to SPL_CLASS", #save name and address to database
        "get input VARI", # get input k
        "Write a FUNC_PROG named FUNC_NAME to CMD_PRNT 'Hello World!' on screen", #write a function named func1 to print "Hello World!" on screen
        
          ]  

input_txt3 = [
    "Write a FUNC_PROG FUNC_NAME to perform OPER with VARI, DTYPE_NUM VARI EQUAL RAND_NUM", #Create a func func_name to perform addition with var1 and numbers value1 = 15 and b               
]

#input_txt=["OPER SCOPE_OFVAR DTYPE_NUM VARI and VARI"]
           
training_data = generate_training_data(input_txt)
training_data2 = generate_training_data(input_txt2)
training_data3 = generate_training_data(input_txt3)

print ("Length: " + str( len(training_data) ) )
print ("Length: " + str( len(training_data2) ) )
print ("Length: " + str( len(training_data3) ) )
# Out:
# eachLine: FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE
# eachLine: FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE_NUM equal to RAND_NUM
# eachLine: FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE_NUM VARI=RAND_NUM
# eachLine: FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE VARI
# eachLine: FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE_NUM to RAND_NUM
# eachLine: FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE equal VARI to RAND_NUM
# eachLine: FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE_CHAR = 'hi'
# eachLine: FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE_CHAR to 'hi'
# eachLine: FUNC_PROG_START CMD_DECL SCOPE_OFVAR VARI = 'hi'
# eachLine: FUNC_PROG_START CMD_DECL SCOPE_OFVAR VARI to 'hi'
# eachLine: FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE_CHAR VARI = 'please enter value'
# eachLine: FUNC_PROG_START CMD_DECL SCOPE_OFVAR DTYPE_CHAR VARI to 'please enter value'
# eachLine: FUNC_PROG_START CMD_PRNT VARI
# eachLine: FUNC_PROG_START CMD_PRNT 'please select value'
# eachLine: FUNC_PROG_START CMD_PRNT 'please select value' + VARI
# eachLine: FUNC_PROG_START CMD_PRNT VARI + i
# eachLine: FUNC_PROG_START CMD_PRNT 'please select value' + i
# eachLine: FUNC_PROG_START CMD_INPUT VARI
# eachLine: FUNC_PROG_START CMD_INPUT 'please enter name'
# eachLine: FUNC_PROG_START add VARI + VARI
# eachLine: FUNC_PROG_START VARI - VARI
# eachLine: FUNC_PROG_START divide VARI / VARI
# eachLine: FUNC_PROG_START OPER SCOPE_OFVAR DTYPE_NUM VARI and VARI
# eachLine: FUNC_PROG_START OPER SCOPE_OFVAR DTYPE_NUM VARI = RAND_NUM and SCOPE_OFVAR VARI = RAND_NUM and DTYPE_NUM VARI = RAND_NUM
# eachLine: FUNC_PROG_START OPER SCOPE_OFVAR DTYPE_NUM VARI, SCOPE_OFVAR VARI = RAND_NUM and SCOPE_OFVAR DTYPE_NUM VARI
# eachLine: FUNC_PROG_START CMD_PRNT DTYPE_CHAR VARI equals to 'some thing something hello there. General Kenobi' on SPL_CLASS
# eachLine: CMD_PRNT VARI on screen
# eachLine: CMD_PRNT VARI to SPL_CLASS
# eachLine: SPL_FUNC VARI
# eachLine: SPL_FUNC VARI and VARI
# eachLine: SPL_FUNC VARI to SPL_CLASS
# eachLine: SPL_FUNC VARI and VARI to SPL_CLASS
# eachLine: get input VARI
# eachLine: Write a FUNC_PROG named FUNC_NAME to CMD_PRNT 'Hello World!' on screen
# eachLine: Write a FUNC_PROG FUNC_NAME to perform OPER with VARI, DTYPE_NUM VARI EQUAL  RAND_NUM and VARI
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-2021f6ce8f38> in <module>
#      87 training_data = generate_training_data(input_txt)
#      88 training_data2 = generate_training_data(input_txt2)
# ---> 89 training_data3 = generate_training_data(input_txt3)
#      90
#      91 print ("Length: " + str( len(training_data) ) )
#
# <ipython-input-8-d3ec75a9eba6> in generate_training_data(input_txt)
#      90             temp_gen_data2.append(tmp_txt)
#      91         else:
# ---> 92             temp_gen_data2.append(eachLine)
#      93     return (temp_gen_data2)
#      94
#
# KeyboardInterrupt:

# %%
# Remove random lines from the file
#3,81,123 is a lot of lines to train
#Update 4,13,784
#Update 9,59,127 - 3 Mar 2021

import random

def reduce_data(original_data, div_factor):
    index_to_delete = []
    loop_size = len(original_data)
    current_iteration = 0
    while( (current_iteration + div_factor) < loop_size ):
        rand_num = random.randint(1,div_factor)
        index_pos = current_iteration + rand_num    
        index_to_delete.append(index_pos)    
        current_iteration += div_factor
    #print("index_to_delete:\n", index_to_delete)
    #final_list = [i for j, i in enumerate(original_data) if j in index_to_delete]
    final_list = [original_data[i] for i in index_to_delete]
    return (final_list)

final_list = reduce_data(training_data, 25)
final_list += reduce_data(training_data2, 5)

print(len(final_list))
# Out:
# 101993

# %%
with open ("Output.txt","w") as output_file:
    for data in final_list:
        output_file.write("{}\n".format(data))
